# %%
import pandas as pd
import requests
import os, sys, inspect
import numpy as np
import matplotlib.pyplot as plt
# add parent dir to system dir
currdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
rootdir = os.path.dirname(currdir)
sys.path.insert(0, rootdir)

from src.config import googleapikey

# %%
ffname = os.path.join(rootdir, "data", "int", "zip_codes.csv")
biz_by_zip_df = pd.read_csv(ffname, header=None, names=["Zip Code"])

biz_by_zip_df.head()
# Out:
#    Zip Code
# 0     78701
# 1     78702
# 2     78703
# 3     78704
# 4     78705

# %%
#adding lat/lon columns for google search
biz_by_zip_df["Lat"] = ""
biz_by_zip_df["Lng"] = ""

# set up params
params = {
    "key": googleapikey
}

# Loop through and grab the lat/lng using Google maps
for index, row in biz_by_zip_df.iterrows():

    # update params with zipcode each loop
    params['address'] = row['Zip Code']

    base_url = "https://maps.googleapis.com/maps/api/geocode/json"

    # Run requests to grab the JSON at the requested URL
    zip_location = requests.get(base_url, params=params)
    print(zip_location.url)

    zip_location = zip_location.json()

    # Append the lat/lng to the appropriate columns
    # Use try / except to skip any cities with errors
    try:
        zip_lat = zip_location["results"][0]["geometry"]["location"]["lat"]
        zip_lng = zip_location["results"][0]["geometry"]["location"]["lng"]

        biz_by_zip_df.loc[index, "Lat"] = zip_lat
        biz_by_zip_df.loc[index, "Lng"] = zip_lng

    except (KeyError, IndexError):
        print("Error with city data. Skipping")

        # drops rows with errors
        biz_by_zip_df.drop(labels=index, inplace=True)


# Visualize
biz_by_zip_df.head()
# Out:
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78701
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78702
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78703
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78704
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78705
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78717
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78721
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78722
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78723
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78724
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78725
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78726
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78727
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78728
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78729
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78730
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78731
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78732
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78733
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78734
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78735
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78736
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78737
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78738
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78739
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78741
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78744
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78745
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78746
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78747
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78748
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78749
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78750
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78751
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78752
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78753
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78754
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78756
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78757
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78758
# https://maps.googleapis.com/maps/api/geocode/json?key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&address=78759
#    Zip Code      Lat      Lng
# 0     78701  30.2729 -97.7444
# 1     78702  30.2604 -97.7145
# 2     78703  30.2915 -97.7688
# 3     78704  30.2457 -97.7688
# 4     78705  30.2962  -97.739

# %% [markdown]
# Bank Count

# %%
# Create an empty column for bank count
biz_by_zip_df["Bank Count"] = ""

# Set up params
params = {
    "radius": 5000,
    "type": "bank",
    "key": googleapikey
}

# Loop through and run Google search to get all banks in 3.1 mile radius (5000 meters)
for index, row in biz_by_zip_df.iterrows():

    # Get lat/lng from df
    lat = row['Lat']
    lng = row['Lng']

    # Update params
    params['location'] = f"{lat},{lng}"

    # Create endpoint url using Google Places Radar and the lat/lng we identified earlier
    base_url = "https://maps.googleapis.com/maps/api/place/radarsearch/json"

    # Run a request, print the url, and convert to json
    bank_data = requests.get(base_url, params=params)
    print(bank_data.url)
    bank_data = bank_data.json()

    # Measure bank count on the number of results in the retrieved area
    bank_count = len(bank_data["results"])

    print(f"Final Bank Count: {bank_count}")
    print("")

    # Store the bank count into the Data Frame
    biz_by_zip_df.loc[index, "Bank Count"] = bank_count

    # Reset bank_count (so there is no chance that a previous record is influencing a latter one)
    bank_count = 0

# Visualize
biz_by_zip_df.head()
# Out:
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2729209%2C-97.74438630000002
# Final Bank Count: 109
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2603535%2C-97.7145152
# Final Bank Count: 79
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2915328%2C-97.76883579999999
# Final Bank Count: 110
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.24567279999999%2C-97.76883579999999
# Final Bank Count: 95
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2961708%2C-97.73895429999999
# Final Bank Count: 108
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4916577%2C-97.7742702
# Final Bank Count: 27
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2737366%2C-97.68194299999999
# Final Bank Count: 13
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2920434%2C-97.7118003
# Final Bank Count: 98
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3081307%2C-97.68194299999999
# Final Bank Count: 22
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2944269%2C-97.6222665
# Final Bank Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2316673%2C-97.6168439
# Final Bank Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4190616%2C-97.8395151
# Final Bank Count: 13
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.432242%2C-97.7145152
# Final Bank Count: 51
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4570672%2C-97.68194299999999
# Final Bank Count: 32
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4646593%2C-97.7471025
# Final Bank Count: 30
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3732514%2C-97.8395151
# Final Bank Count: 17
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3542409%2C-97.7742702
# Final Bank Count: 41
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3788578%2C-97.8923749
# Final Bank Count: 10
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.33151879999999%2C-97.86671820000001
# Final Bank Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3666665%2C-97.9483898
# Final Bank Count: 23
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2573497%2C-97.86127669999999
# Final Bank Count: 26
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.25208559999999%2C-97.9483898
# Final Bank Count: 2
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.18196499999999%2C-97.9701846
# Final Bank Count: 2
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2966026%2C-97.9701846
# Final Bank Count: 20
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.1859258%2C-97.90482
# Final Bank Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2259488%2C-97.7145152
# Final Bank Count: 25
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.196311%2C-97.730807
# Final Bank Count: 13
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2153869%2C-97.7960118
# Final Bank Count: 34
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2962208%2C-97.8299383
# Final Bank Count: 27
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.1274614%2C-97.730807
# Final Bank Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.168207%2C-97.8177601
# Final Bank Count: 17
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2175453%2C-97.8558357
# Final Bank Count: 27
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4270699%2C-97.8014482
# Final Bank Count: 25
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3055711%2C-97.725376
# Final Bank Count: 104
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3317278%2C-97.70515800000001
# Final Bank Count: 57
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3889868%2C-97.6710889
# Final Bank Count: 38
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3558863%2C-97.64938579999999
# Final Bank Count: 13
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3248256%2C-97.73895429999999
# Final Bank Count: 78
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3568213%2C-97.730807
# Final Bank Count: 71
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3870686%2C-97.70365609999999
# Final Bank Count: 78
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=bank&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.401356%2C-97.7525352
# Final Bank Count: 54
#    Zip Code      Lat      Lng  Bank Count
# 0     78701  30.2729 -97.7444         109
# 1     78702  30.2604 -97.7145          79
# 2     78703  30.2915 -97.7688         110
# 3     78704  30.2457 -97.7688          95
# 4     78705  30.2962  -97.739         108

# %% [markdown]
# Liquor Store Count

# %%
# Create an empty column for liquor store count
biz_by_zip_df["Liquor Store Count"] = ""

# Set up params
params = {
    "radius": 5000,
    "type": "liquor_store",
    "key": googleapikey
}

# Loop through and run Google search to get all liquor stores in 3.1 mile radius (5000 meters)
for index, row in biz_by_zip_df.iterrows():

    # Get lat/lng from df
    lat = row['Lat']
    lng = row['Lng']

    # Update params
    params['location'] = f"{lat},{lng}"

    # Create endpoint url using Google Places Radar and the lat/lng we identified earlier
    base_url = "https://maps.googleapis.com/maps/api/place/radarsearch/json"

    # Run a request, print the url, and convert to json
    liquor_data = requests.get(base_url, params=params)
    print(liquor_data.url)
    liquor_data = liquor_data.json()

    # Measure liquor store count on the number of results in the retrieved area
    liquor_count = len(liquor_data["results"])

    print(f"Final Liquor Store Count: {liquor_count}")
    print("")

    # Store the liquor store count into the Data Frame
    biz_by_zip_df.loc[index, "Liquor Store Count"] = liquor_count

    # Reset liquor_count (so there is no chance that a previous record is influencing a latter one)
    liquor_count = 0

# Visualize
biz_by_zip_df.head()
# Out:
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2729209%2C-97.74438630000002
# Final Liquor Store Count: 61
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2603535%2C-97.7145152
# Final Liquor Store Count: 54
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2915328%2C-97.76883579999999
# Final Liquor Store Count: 46
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.24567279999999%2C-97.76883579999999
# Final Liquor Store Count: 52
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2961708%2C-97.73895429999999
# Final Liquor Store Count: 54
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4916577%2C-97.7742702
# Final Liquor Store Count: 12
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2737366%2C-97.68194299999999
# Final Liquor Store Count: 18
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2920434%2C-97.7118003
# Final Liquor Store Count: 50
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3081307%2C-97.68194299999999
# Final Liquor Store Count: 24
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2944269%2C-97.6222665
# Final Liquor Store Count: 2
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2316673%2C-97.6168439
# Final Liquor Store Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4190616%2C-97.8395151
# Final Liquor Store Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.432242%2C-97.7145152
# Final Liquor Store Count: 17
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4570672%2C-97.68194299999999
# Final Liquor Store Count: 14
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4646593%2C-97.7471025
# Final Liquor Store Count: 10
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3732514%2C-97.8395151
# Final Liquor Store Count: 2
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3542409%2C-97.7742702
# Final Liquor Store Count: 17
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3788578%2C-97.8923749
# Final Liquor Store Count: 5
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.33151879999999%2C-97.86671820000001
# Final Liquor Store Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3666665%2C-97.9483898
# Final Liquor Store Count: 5
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2573497%2C-97.86127669999999
# Final Liquor Store Count: 6
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.25208559999999%2C-97.9483898
# Final Liquor Store Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.18196499999999%2C-97.9701846
# Final Liquor Store Count: 4
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2966026%2C-97.9701846
# Final Liquor Store Count: 4
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.1859258%2C-97.90482
# Final Liquor Store Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2259488%2C-97.7145152
# Final Liquor Store Count: 24
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.196311%2C-97.730807
# Final Liquor Store Count: 12
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2153869%2C-97.7960118
# Final Liquor Store Count: 22
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2962208%2C-97.8299383
# Final Liquor Store Count: 8
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.1274614%2C-97.730807
# Final Liquor Store Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.168207%2C-97.8177601
# Final Liquor Store Count: 14
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2175453%2C-97.8558357
# Final Liquor Store Count: 13
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4270699%2C-97.8014482
# Final Liquor Store Count: 8
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3055711%2C-97.725376
# Final Liquor Store Count: 56
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3317278%2C-97.70515800000001
# Final Liquor Store Count: 36
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3889868%2C-97.6710889
# Final Liquor Store Count: 10
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3558863%2C-97.64938579999999
# Final Liquor Store Count: 9
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3248256%2C-97.73895429999999
# Final Liquor Store Count: 39
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3568213%2C-97.730807
# Final Liquor Store Count: 34
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3870686%2C-97.70365609999999
# Final Liquor Store Count: 27
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&type=liquor_store&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.401356%2C-97.7525352
# Final Liquor Store Count: 22
#    Zip Code      Lat      Lng  Bank Count  Liquor Store Count
# 0     78701  30.2729 -97.7444         109                  61
# 1     78702  30.2604 -97.7145          79                  54
# 2     78703  30.2915 -97.7688         110                  46
# 3     78704  30.2457 -97.7688          95                  52
# 4     78705  30.2962  -97.739         108                  54

# %% [markdown]
# Wal-Mart Count

# %%
# Create an empty column for walmart count
biz_by_zip_df["Wal-Mart Count"] = ""

# Set up params
params = {
    "radius": 5000,
    "name": "Wal-Mart",
    "key": googleapikey
}

# Loop through and run Google search to get all walmarts in 3.1 mile radius (5000 meters)
for index, row in biz_by_zip_df.iterrows():

    # Get lat/lng from df
    lat = row['Lat']
    lng = row['Lng']

    # Update params
    params['location'] = f"{lat},{lng}"

    # Create endpoint url using Google Places Radar and the lat/lng we identified earlier
    base_url = "https://maps.googleapis.com/maps/api/place/radarsearch/json"

    # Run a request, print the url, and convert to json
    walmart_data = requests.get(base_url, params=params)
    print(walmart_data.url)
    walmart_data = walmart_data.json()

    # Measure walmart count on the number of results in the retrieved area
    walmart_count = len(walmart_data["results"])

    print(f"Final Wal-Mart Count: {walmart_count}")
    print("")

    # Store the walmart count into the Data Frame
    biz_by_zip_df.loc[index, "Wal-Mart Count"] = walmart_count

    # Reset walmart_count (so there is no chance that a previous record is influencing a latter one)
    walmart_count = 0

# Visualize
biz_by_zip_df.head()
# Out:
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2729209%2C-97.74438630000002
# Final Wal-Mart Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2603535%2C-97.7145152
# Final Wal-Mart Count: 15
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2915328%2C-97.76883579999999
# Final Wal-Mart Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.24567279999999%2C-97.76883579999999
# Final Wal-Mart Count: 17
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2961708%2C-97.73895429999999
# Final Wal-Mart Count: 14
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4916577%2C-97.7742702
# Final Wal-Mart Count: 20
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2737366%2C-97.68194299999999
# Final Wal-Mart Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2920434%2C-97.7118003
# Final Wal-Mart Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3081307%2C-97.68194299999999
# Final Wal-Mart Count: 13
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2944269%2C-97.6222665
# Final Wal-Mart Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2316673%2C-97.6168439
# Final Wal-Mart Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4190616%2C-97.8395151
# Final Wal-Mart Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.432242%2C-97.7145152
# Final Wal-Mart Count: 14
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4570672%2C-97.68194299999999
# Final Wal-Mart Count: 27
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4646593%2C-97.7471025
# Final Wal-Mart Count: 11
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3732514%2C-97.8395151
# Final Wal-Mart Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3542409%2C-97.7742702
# Final Wal-Mart Count: 10
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3788578%2C-97.8923749
# Final Wal-Mart Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.33151879999999%2C-97.86671820000001
# Final Wal-Mart Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3666665%2C-97.9483898
# Final Wal-Mart Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2573497%2C-97.86127669999999
# Final Wal-Mart Count: 10
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.25208559999999%2C-97.9483898
# Final Wal-Mart Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.18196499999999%2C-97.9701846
# Final Wal-Mart Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2966026%2C-97.9701846
# Final Wal-Mart Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.1859258%2C-97.90482
# Final Wal-Mart Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2259488%2C-97.7145152
# Final Wal-Mart Count: 15
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.196311%2C-97.730807
# Final Wal-Mart Count: 14
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2153869%2C-97.7960118
# Final Wal-Mart Count: 26
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2962208%2C-97.8299383
# Final Wal-Mart Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.1274614%2C-97.730807
# Final Wal-Mart Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.168207%2C-97.8177601
# Final Wal-Mart Count: 11
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2175453%2C-97.8558357
# Final Wal-Mart Count: 12
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4270699%2C-97.8014482
# Final Wal-Mart Count: 10
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3055711%2C-97.725376
# Final Wal-Mart Count: 14
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3317278%2C-97.70515800000001
# Final Wal-Mart Count: 23
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3889868%2C-97.6710889
# Final Wal-Mart Count: 14
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3558863%2C-97.64938579999999
# Final Wal-Mart Count: 13
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3248256%2C-97.73895429999999
# Final Wal-Mart Count: 23
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3568213%2C-97.730807
# Final Wal-Mart Count: 23
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3870686%2C-97.70365609999999
# Final Wal-Mart Count: 24
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Wal-Mart&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.401356%2C-97.7525352
# Final Wal-Mart Count: 1
#    Zip Code      Lat      Lng  Bank Count  Liquor Store Count  Wal-Mart Count
# 0     78701  30.2729 -97.7444         109                  61               1
# 1     78702  30.2604 -97.7145          79                  54              15
# 2     78703  30.2915 -97.7688         110                  46               1
# 3     78704  30.2457 -97.7688          95                  52              17
# 4     78705  30.2962  -97.739         108                  54              14

# %% [markdown]
# Target Count

# %%
# Create an empty column for target count
biz_by_zip_df["Target Count"] = ""

# Set up params
params = {
    "radius": 5000,
    "name": "Target",
    "key": googleapikey
}

# Loop through and run Google search to get all Targets in 3.1 mile radius (5000 meters)
for index, row in biz_by_zip_df.iterrows():

    # Get lat/lng from df
    lat = row['Lat']
    lng = row['Lng']

    # Update params
    params['location'] = f"{lat},{lng}"

    # Create endpoint url using Google Places Radar and the lat/lng we identified earlier
    base_url = "https://maps.googleapis.com/maps/api/place/radarsearch/json"

    # Run a request, print the url, and convert to json
    target_data = requests.get(base_url, params=params)
    print(target_data.url)
    target_data = target_data.json()

    # Measure target count on the number of results in the retrieved area
    target_count = len(target_data["results"])

    print(f"Final Target Count: {target_count}")
    print("")

    # Store the target count into the Data Frame
    biz_by_zip_df.loc[index, "Target Count"] = target_count

    # Reset target_count (so there is no chance that a previous record is influencing a latter one)
    target_count = 0

# Visualize
biz_by_zip_df.head()
# Out:
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2729209%2C-97.74438630000002
# Final Target Count: 7
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2603535%2C-97.7145152
# Final Target Count: 2
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2915328%2C-97.76883579999999
# Final Target Count: 2
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.24567279999999%2C-97.76883579999999
# Final Target Count: 5
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2961708%2C-97.73895429999999
# Final Target Count: 4
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4916577%2C-97.7742702
# Final Target Count: 7
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2737366%2C-97.68194299999999
# Final Target Count: 2
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2920434%2C-97.7118003
# Final Target Count: 4
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3081307%2C-97.68194299999999
# Final Target Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2944269%2C-97.6222665
# Final Target Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2316673%2C-97.6168439
# Final Target Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4190616%2C-97.8395151
# Final Target Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.432242%2C-97.7145152
# Final Target Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4570672%2C-97.68194299999999
# Final Target Count: 2
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4646593%2C-97.7471025
# Final Target Count: 4
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3732514%2C-97.8395151
# Final Target Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3542409%2C-97.7742702
# Final Target Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3788578%2C-97.8923749
# Final Target Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.33151879999999%2C-97.86671820000001
# Final Target Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3666665%2C-97.9483898
# Final Target Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2573497%2C-97.86127669999999
# Final Target Count: 2
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.25208559999999%2C-97.9483898
# Final Target Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.18196499999999%2C-97.9701846
# Final Target Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2966026%2C-97.9701846
# Final Target Count: 2
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.1859258%2C-97.90482
# Final Target Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2259488%2C-97.7145152
# Final Target Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.196311%2C-97.730807
# Final Target Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2153869%2C-97.7960118
# Final Target Count: 5
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2962208%2C-97.8299383
# Final Target Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.1274614%2C-97.730807
# Final Target Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.168207%2C-97.8177601
# Final Target Count: 6
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2175453%2C-97.8558357
# Final Target Count: 2
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4270699%2C-97.8014482
# Final Target Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3055711%2C-97.725376
# Final Target Count: 5
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3317278%2C-97.70515800000001
# Final Target Count: 5
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3889868%2C-97.6710889
# Final Target Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3558863%2C-97.64938579999999
# Final Target Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3248256%2C-97.73895429999999
# Final Target Count: 7
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3568213%2C-97.730807
# Final Target Count: 8
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3870686%2C-97.70365609999999
# Final Target Count: 6
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Target&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.401356%2C-97.7525352
# Final Target Count: 4
#    Zip Code      Lat      Lng  Bank Count  Liquor Store Count  Wal-Mart Count  \
# 0     78701  30.2729 -97.7444         109                  61               1
# 1     78702  30.2604 -97.7145          79                  54              15
# 2     78703  30.2915 -97.7688         110                  46               1
# 3     78704  30.2457 -97.7688          95                  52              17
# 4     78705  30.2962  -97.739         108                  54              14
#
#    Starbucks Count  Target Count
# 0               29             7
# 1               24             2
# 2               22             2
# 3               27             5
# 4               23             4

# %% [markdown]
# Starbucks Count

# %%
# Create an empty column for Starbucks count
biz_by_zip_df["Starbucks Count"] = ""

# Set up params
params = {
    "radius": 5000,
    "name": "Starbucks",
    "key": googleapikey
}

# Loop through and run Google search to get all Starbucks in 3.1 mile radius (5000 meters)
for index, row in biz_by_zip_df.iterrows():

    # Get lat/lng from df
    lat = row['Lat']
    lng = row['Lng']

    # Update params
    params['location'] = f"{lat},{lng}"

    # Create endpoint url using Google Places Radar and the lat/lng we identified earlier
    base_url = "https://maps.googleapis.com/maps/api/place/radarsearch/json"

    # Run a request, print the url, and convert to json
    starbucks_data = requests.get(base_url, params=params)
    print(starbucks_data.url)
    starbucks_data = starbucks_data.json()

    # Measure Starbucks count on the number of results in the retrieved area
    starbucks_count = len(starbucks_data["results"])

    print(f"Final Starbucks Count: {starbucks_count}")
    print("")

    # Store the Starbucks count into the Data Frame
    biz_by_zip_df.loc[index, "Starbucks Count"] = starbucks_count

    # Reset starbucks_count (so there is no chance that a previous record is influencing a latter one)
    starbucks_count = 0

# Visualize
biz_by_zip_df.head()
# Out:
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2729209%2C-97.74438630000002
# Final Starbucks Count: 29
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2603535%2C-97.7145152
# Final Starbucks Count: 24
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2915328%2C-97.76883579999999
# Final Starbucks Count: 22
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.24567279999999%2C-97.76883579999999
# Final Starbucks Count: 27
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2961708%2C-97.73895429999999
# Final Starbucks Count: 23
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4916577%2C-97.7742702
# Final Starbucks Count: 11
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2737366%2C-97.68194299999999
# Final Starbucks Count: 5
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2920434%2C-97.7118003
# Final Starbucks Count: 22
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3081307%2C-97.68194299999999
# Final Starbucks Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2944269%2C-97.6222665
# Final Starbucks Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2316673%2C-97.6168439
# Final Starbucks Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4190616%2C-97.8395151
# Final Starbucks Count: 5
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.432242%2C-97.7145152
# Final Starbucks Count: 9
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4570672%2C-97.68194299999999
# Final Starbucks Count: 6
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4646593%2C-97.7471025
# Final Starbucks Count: 4
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3732514%2C-97.8395151
# Final Starbucks Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3542409%2C-97.7742702
# Final Starbucks Count: 8
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3788578%2C-97.8923749
# Final Starbucks Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.33151879999999%2C-97.86671820000001
# Final Starbucks Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3666665%2C-97.9483898
# Final Starbucks Count: 2
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2573497%2C-97.86127669999999
# Final Starbucks Count: 6
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.25208559999999%2C-97.9483898
# Final Starbucks Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.18196499999999%2C-97.9701846
# Final Starbucks Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2966026%2C-97.9701846
# Final Starbucks Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.1859258%2C-97.90482
# Final Starbucks Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2259488%2C-97.7145152
# Final Starbucks Count: 14
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.196311%2C-97.730807
# Final Starbucks Count: 3
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2153869%2C-97.7960118
# Final Starbucks Count: 13
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2962208%2C-97.8299383
# Final Starbucks Count: 4
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.1274614%2C-97.730807
# Final Starbucks Count: 0
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.168207%2C-97.8177601
# Final Starbucks Count: 4
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.2175453%2C-97.8558357
# Final Starbucks Count: 8
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.4270699%2C-97.8014482
# Final Starbucks Count: 7
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3055711%2C-97.725376
# Final Starbucks Count: 22
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3317278%2C-97.70515800000001
# Final Starbucks Count: 9
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3889868%2C-97.6710889
# Final Starbucks Count: 4
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3558863%2C-97.64938579999999
# Final Starbucks Count: 1
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3248256%2C-97.73895429999999
# Final Starbucks Count: 14
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3568213%2C-97.730807
# Final Starbucks Count: 8
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.3870686%2C-97.70365609999999
# Final Starbucks Count: 11
#
# https://maps.googleapis.com/maps/api/place/radarsearch/json?radius=5000&name=Starbucks&key=AIzaSyDUm_T-Gud02p8_cUhB_De4EnLKxp6KNUE&location=30.401356%2C-97.7525352
# Final Starbucks Count: 11
#    Zip Code      Lat      Lng  Bank Count  Liquor Store Count  Wal-Mart Count  \
# 0     78701  30.2729 -97.7444         109                  61               1
# 1     78702  30.2604 -97.7145          79                  54              15
# 2     78703  30.2915 -97.7688         110                  46               1
# 3     78704  30.2457 -97.7688          95                  52              17
# 4     78705  30.2962  -97.739         108                  54              14
#
#    Starbucks Count
# 0               29
# 1               24
# 2               22
# 3               27
# 4               23

# %%
output = os.path.join(rootdir, "data", "int", "businesses_by_zip.csv")
biz_by_zip_df.to_csv(output, index=False)
biz_by_zip_df
# Out:
#     Zip Code      Lat      Lng  Bank Count  Liquor Store Count  \
# 0      78701  30.2729 -97.7444         109                  61
# 1      78702  30.2604 -97.7145          79                  54
# 2      78703  30.2915 -97.7688         110                  46
# 3      78704  30.2457 -97.7688          95                  52
# 4      78705  30.2962  -97.739         108                  54
# 5      78717  30.4917 -97.7743          27                  12
# 6      78721  30.2737 -97.6819          13                  18
# 7      78722   30.292 -97.7118          98                  50
# 8      78723  30.3081 -97.6819          22                  24
# 9      78724  30.2944 -97.6223           0                   2
# 10     78725  30.2317 -97.6168           0                   3
# 11     78726  30.4191 -97.8395          13                   3
# 12     78727  30.4322 -97.7145          51                  17
# 13     78728  30.4571 -97.6819          32                  14
# 14     78729  30.4647 -97.7471          30                  10
# 15     78730  30.3733 -97.8395          17                   2
# 16     78731  30.3542 -97.7743          41                  17
# 17     78732  30.3789 -97.8924          10                   5
# 18     78733  30.3315 -97.8667           3                   0
# 19     78734  30.3667 -97.9484          23                   5
# 20     78735  30.2573 -97.8613          26                   6
# 21     78736  30.2521 -97.9484           2                   1
# 22     78737   30.182 -97.9702           2                   4
# 23     78738  30.2966 -97.9702          20                   4
# 24     78739  30.1859 -97.9048           3                   3
# 25     78741  30.2259 -97.7145          25                  24
# 26     78744  30.1963 -97.7308          13                  12
# 27     78745  30.2154  -97.796          34                  22
# 28     78746  30.2962 -97.8299          27                   8
# 29     78747  30.1275 -97.7308           0                   0
# 30     78748  30.1682 -97.8178          17                  14
# 31     78749  30.2175 -97.8558          27                  13
# 32     78750  30.4271 -97.8014          25                   8
# 33     78751  30.3056 -97.7254         104                  56
# 34     78752  30.3317 -97.7052          57                  36
# 35     78753   30.389 -97.6711          38                  10
# 36     78754  30.3559 -97.6494          13                   9
# 37     78756  30.3248  -97.739          78                  39
# 38     78757  30.3568 -97.7308          71                  34
# 39     78758  30.3871 -97.7037          78                  27
# 40     78759  30.4014 -97.7525          54                  22
#
#     Wal-Mart Count  Starbucks Count  Target Count
# 0                1               29             7
# 1               15               24             2
# 2                1               22             2
# 3               17               27             5
# 4               14               23             4
# 5               20               11             7
# 6                0                5             2
# 7                1               22             4
# 8               13                3             3
# 9                0                0             1
# 10               1                0             0
# 11               1                5             1
# 12              14                9             3
# 13              27                6             2
# 14              11                4             4
# 15               1                3             1
# 16              10                8             3
# 17               1                3             1
# 18               1                1             0
# 19               1                2             0
# 20              10                6             2
# 21               0                0             0
# 22               0                0             0
# 23               1                3             2
# 24               1                1             1
# 25              15               14             0
# 26              14                3             0
# 27              26               13             5
# 28               1                4             0
# 29               0                0             0
# 30              11                4             6
# 31              12                8             2
# 32              10                7             1
# 33              14               22             5
# 34              23                9             5
# 35              14                4             3
# 36              13                1             0
# 37              23               14             7
# 38              23                8             8
# 39              24               11             6
# 40               1               11             4
