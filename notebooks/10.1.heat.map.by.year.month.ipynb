# %%
import pandas as pd
import numpy as np
import os, sys, inspect

# add parent dir to system dir
currdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
rootdir = os.path.dirname(currdir)
sys.path.insert(0, rootdir)

from src.utils import get_temporal_data, get_spatial_data

# %%
ffname_realestate = os.path.join(rootdir, "data", "int", "realestate_demographics.csv")
realestate_df = pd.read_csv(ffname_realestate)

# %%
ziptrend = get_temporal_data(78701,realestate_df)

# %%
ziptrend.head()
# Out:
#    Zip Code  Year  Month  Home Value Index  Median Listing Price  \
# 0     78701  1996      4          152500.0                   NaN
# 1     78701  1996      5          153600.0                   NaN
# 2     78701  1996      6          154600.0                   NaN
# 3     78701  1996      7          155500.0                   NaN
# 4     78701  1996      8          156300.0                   NaN
#
#    Median Listing Price Per sqf  Sales  Median Income (dollars)  \
# 0                           NaN    NaN                      NaN
# 1                           NaN    NaN                      NaN
# 2                           NaN    NaN                      NaN
# 3                           NaN    NaN                      NaN
# 4                           NaN    NaN                      NaN
#
#    Number of Households  Mortgage Rate_15  Mortgage Rate_30  \
# 0                   NaN               NaN               NaN
# 1                   NaN              7.54              8.03
# 2                   NaN              7.82              8.29
# 3                   NaN              7.71              8.19
# 4                   NaN              7.60              8.09
#
#    Total_NewConstructions  Total_RemodelsRepairs  TotalCost_NewConstructions  \
# 0                     NaN                    NaN                         NaN
# 1                     NaN                    NaN                         NaN
# 2                     NaN                    NaN                         NaN
# 3                     3.0                   71.0                    216470.0
# 4                     NaN                    NaN                         NaN
#
#    TotalCost_RemodelRepairs  Inventory Measure  Median Price Cut  \
# 0                       NaN                NaN               NaN
# 1                       NaN                NaN               NaN
# 2                       NaN                NaN               NaN
# 3                    4000.0                NaN               NaN
# 4                       NaN                NaN               NaN
#
#    Median Price of Reduction  Median Rental Price
# 0                        NaN                  NaN
# 1                        NaN                  NaN
# 2                        NaN                  NaN
# 3                        NaN                  NaN
# 4                        NaN                  NaN

# %%
yeartrend = get_spatial_data(2012,realestate_df)
yeartrend.head()
# Out:
#      Zip Code  Year  Month  Home Value Index  Median Listing Price  \
# 189     78701  2012      1          268700.0                   NaN
# 190     78701  2012      2          269200.0                   NaN
# 191     78701  2012      3          269800.0                   NaN
# 192     78701  2012      4          268800.0                   NaN
# 193     78701  2012      5          267000.0                   NaN
#
#      Median Listing Price Per sqf  Sales  Median Income (dollars)  \
# 189                    329.810412    8.0                  63873.0
# 190                    327.616929    8.0                  64262.0
# 191                    330.687831   67.0                  64651.0
# 192                    346.828610   14.0                  65040.0
# 193                    375.370971   21.0                  65429.0
#
#      Number of Households  Mortgage Rate_15  Mortgage Rate_30  \
# 189                3235.0              3.24              3.98
# 190                3262.0              3.19              3.95
# 191                3289.0              3.23              3.99
# 192                3316.0              3.12              3.88
# 193                3343.0              2.97              3.75
#
#      Total_NewConstructions  Total_RemodelsRepairs  \
# 189                     0.0                    1.0
# 190                     0.0                    1.0
# 191                     1.0                    2.0
# 192                     0.0                    2.0
# 193                     NaN                    NaN
#
#      TotalCost_NewConstructions  TotalCost_RemodelRepairs  Inventory Measure  \
# 189                         0.0                   15100.0                NaN
# 190                         0.0                   10250.0                NaN
# 191                     25000.0                   42800.0                NaN
# 192                         0.0                  325000.0                NaN
# 193                         NaN                       NaN                NaN
#
#      Median Price Cut  Median Price of Reduction  Median Rental Price
# 189           10000.0                   2.942042               2050.0
# 190           20000.0                   4.264578               2095.0
# 191           10000.0                   1.395797               2200.0
# 192           10000.0                   1.803607               2200.0
# 193           10000.0                   2.962963               2100.0
